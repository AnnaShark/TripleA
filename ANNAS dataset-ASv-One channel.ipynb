# %%
import sys
sys.path.append("D:\python\lib\site-packages")
import pyxdf as xdf
import numpy as np
import matplotlib.pyplot as plt
import mne
# %matplotlib notebook

# %% [markdown]
# ### QUICK START
#
# Run the code below three times, changing the current_xdf value for the 3 xdf files.

# %%
xdf.load_xdf("yoshe_test.xdf")
# Out:
# ([{'info': defaultdict(list,
#                {'name': ['UnityData Stram'],
#                 'type': ['LSL_Marker_Strings'],
#                 'channel_count': ['1'],
#                 'nominal_srate': ['0'],
#                 'channel_format': ['string'],
#                 'source_id': ['D3F83BB699EB49AB94A9FA44B88882AB'],
#                 'version': ['1.1000000000000001'],
#                 'created_at': ['2893.0703176000002'],
#                 'uid': ['8b3d36d2-1312-436a-bc82-29dbee79b6c7'],
#                 'session_id': ['default'],
#                 'hostname': ['LAPTOP-JQKQ10DS'],
#                 'v4address': [None],
#                 'v4data_port': ['16572'],
#                 'v4service_port': ['16572'],
#                 'v6address': [None],
#                 'v6data_port': ['16572'],
#                 'v6service_port': ['16572'],
#                 'desc': [None],
#                 'effective_srate': 0}),
#    'footer': {'info': defaultdict(list,
#                 {'first_timestamp': ['287.5280456542969'],
#                  'last_timestamp': ['687.726806640625'],
#                  'sample_count': ['100'],
#                  'clock_offsets': [defaultdict(list,
#                               {'offset': [defaultdict(list,
#                                             {'time': ['3148.31581385'],
#                                              'value': ['-4.075000015291153e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3153.3164515'],
#                                              'value': ['-1.750000001266017e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3158.31746805'],
#                                              'value': ['2.750000021478627e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3163.317843'],
#                                              'value': ['-2.389999986007751e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3168.3182616'],
#                                              'value': ['-2.820000008796342e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3173.3189359'],
#                                              'value': ['-2.799999947455945e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3178.31977305'],
#                                              'value': ['-1.784999994924874e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3183.3207355'],
#                                              'value': ['-2.300000005561742e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3188.32138725'],
#                                              'value': ['-2.265000011902885e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3193.3217251'],
#                                              'value': ['-1.269999984288006e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3198.32253685'],
#                                              'value': ['-1.454999983252492e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3203.32294955'],
#                                              'value': ['1.694999991741497e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3208.32352875'],
#                                              'value': ['-1.065000014932593e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3213.3242441'],
#                                              'value': ['-2.900000026784255e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3218.32457005'],
#                                              'value': ['-5.649999820889207e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3223.32489115'],
#                                              'value': ['1.650000058361911e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3228.32527025'],
#                                              'value': ['-1.544999986435869e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3233.3260041'],
#                                              'value': ['-3.400000196052133e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3238.32647945'],
#                                              'value': ['-2.655000002960151e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3243.3272387'],
#                                              'value': ['1.160000010713702e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3248.3276497'],
#                                              'value': ['-2.990000007230265e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3253.327894300001'],
#                                              'value': ['-2.930000005108013e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3258.3287022'],
#                                              'value': ['-1.900000006571645e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3263.329709799999'],
#                                              'value': ['-2.269999981763249e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3268.3308934'],
#                                              'value': ['-6.600000006073969e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3273.3315044'],
#                                              'value': ['8.000000207175617e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3278.33244845'],
#                                              'value': ['-1.574999987496994e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3283.3331246'],
#                                              'value': ['-1.750000001266017e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3288.334056100001'],
#                                              'value': ['1.459999998587591e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3293.3350897'],
#                                              'value': ['-2.76000000667409e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3298.3352661'],
#                                              'value': ['-1.750000001266017e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3303.335496'],
#                                              'value': ['-3.209999999853608e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3308.3360388'],
#                                              'value': ['-2.449999988130003e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['
-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3588.37282265'],
#                                              'value': ['-1.044999999066931e-005']})]})]})},
#    'time_series': [['PressedLow_1'],
#     ['RewardNone_1'],
#     ['PressedHigh_2'],
#     ['RewardHigh_2'],
#     ['PressedHigh_3'],
#     ['RewardHigh_3'],
#     ['PressedHigh_4'],
#     ['RewardHigh_4'],
#     ['PressedHigh_5'],
#     ['RewardHigh_5'],
#     ['PressedHigh_6'],
#     ['RewardNone_6'],
#     ['PressedHigh_7'],
#     ['RewardHigh_7'],
#     ['PressedHigh_8'],
#     ['RewardHigh_8'],
#     ['PressedHigh_9'],
#     ['RewardHigh_9'],
#     ['PressedHigh_10'],
#     ['RewardHigh_10'],
#     ['PressedHigh_11'],
#     ['RewardNone_11'],
#     ['PressedHigh_12'],
#     ['RewardNone_12'],
#     ['PressedHigh_13'],
#     ['RewardNone_13'],
#     ['PressedHigh_14'],
#     ['RewardHigh_14'],
#     ['PressedHigh_15'],
#     ['RewardHigh_15'],
#     ['PressedHigh_16'],
#     ['RewardHigh_16'],
#     ['PressedHigh_17'],
#     ['RewardNone_17'],
#     ['PressedLow_18'],
#     ['RewardNone_18'],
#     ['PressedHigh_19'],
#     ['RewardNone_19'],
#     ['PressedHigh_20'],
#     ['RewardHigh_20'],
#     ['PressedHigh_21'],
#     ['RewardHigh_21'],
#     ['PressedHigh_22'],
#     ['RewardNone_22'],
#     ['PressedHigh_23'],
#     ['RewardNone_23'],
#     ['PressedHigh_24'],
#     ['RewardHigh_24'],
#     ['PressedHigh_25'],
#     ['RewardNone_25'],
#     ['PressedHigh_26'],
#     ['RewardHigh_26'],
#     ['PressedHigh_27'],
#     ['RewardNone_27'],
#     ['PressedHigh_28'],
#     ['RewardNone_28'],
#     ['PressedHigh_29'],
#     ['RewardNone_29'],
#     ['PressedHigh_30'],
#     ['RewardHigh_30'],
#     ['PressedHigh_31'],
#     ['RewardHigh_31'],
#     ['PressedHigh_32'],
#     ['RewardHigh_32'],
#     ['PressedHigh_33'],
#     ['RewardHigh_33'],
#     ['PressedHigh_34'],
#     ['RewardNone_34'],
#     ['PressedHigh_35'],
#     ['RewardNone_35'],
#     ['PressedHigh_36'],
#     ['RewardHigh_36'],
#     ['PressedHigh_37'],
#     ['RewardHigh_37'],
#     ['PressedHigh_38'],
#     ['RewardHigh_38'],
#     ['PressedHigh_39'],
#     ['RewardNone_39'],
#     ['PressedHigh_40'],
#     ['RewardNone_40'],
#     ['PressedHigh_41'],
#     ['RewardNone_41'],
#     ['PressedHigh_42'],
#     ['RewardHigh_42'],
#     ['PressedHigh_43'],
#     ['RewardNone_43'],
#     ['PressedHigh_44'],
#     ['RewardHigh_44'],
#     ['PressedHigh_45'],
#     ['RewardNone_45'],
#     ['PressedLow_46'],
#     ['RewardNone_46'],
#     ['PressedHigh_47'],
#     ['RewardHigh_47'],
#     ['PressedHigh_48'],
#     ['RewardNone_48'],
#     ['PressedHigh_49'],
#     ['RewardNone_49'],
#     ['PressedHigh_50'],
#     ['RewardNone_50']],
#    'time_stamps': array([287.52802238, 288.75431022, 300.53610958, 304.11734738,
#           309.83447997, 314.32666748, 317.85471315, 323.14215823,
#           329.57456181, 334.57688117, 340.12674691, 345.52860239,
#           351.77725964, 356.53211195, 359.0202101 , 364.56024918,
#           368.65421281, 374.17218768, 376.52454365, 382.09226217,
#           384.12955466, 389.74689476, 391.93823998, 397.38925929,
#           399.72556301, 405.3258743 , 408.36042021, 413.69620514,
#           415.71732331, 421.35141756, 423.26078036, 428.87860875,
#           430.93244176, 436.568245  , 438.83798988, 444.39038858,
#           446.49436198, 451.94535076, 454.2481767 , 459.94858565,
#           461.95526901, 467.60715501, 469.18140428, 474.85199756,
#           477.63871022, 483.24051688, 485.32764457, 490.94651055,
#           492.80213189, 498.48542049, 500.3429034 , 505.97748594,
#           507.99897032, 513.58463318, 515.67160828, 521.08969912,
#           523.02909122, 528.51554143, 531.18338812, 536.85007515,
#           538.64267769, 544.19565622, 545.90213816, 551.48642773,
#           553.53977246, 558.86118361, 561.06485793, 566.73203324,
#           569.39957476, 574.98325397, 577.09104207, 582.3605123 ,
#           584.08268027, 589.76651818, 591.62168176, 597.22391566,
#           599.09787807, 604.71701871, 606.63803923, 612.28775848,
#           614.27573456, 619.94217745, 621.7160422 , 627.36667699,
#           629.05515355, 634.74118873, 636.61228248, 642.11789773,
#           643.79325174, 649.42795635, 651.23404766, 656.90085676,
#           658.30899886, 664.02689438, 665.40543443, 671.08774646,
#           672.66196521, 678.29642568, 684.32749259, 687.72678459])},
#   {'info': defaultdict(list,
#                {'name': ['openvibeMarkers'],
#                 'type': ['Markers'],
#                 'channel_count': ['1'],
#                 'nominal_srate': ['0'],
#                 'channel_format': ['int32'],
#                 'source_id': ['(0x74ad4eae, 0x5d240588)'],
#                 'version': ['1'],
#                 'created_at': ['2987.2241150999998'],
#                 'uid': ['c898011d-07b3-4adc-b890-5bd3b2ca5603'],
#                 'session_id': ['default'],
#                 'hostname': ['LAPTOP-JQKQ10DS'],
#                 'v4address': [None],
#                 'v4data_port': ['16574'],
#                 'v4service_port': ['16574'],
#                 'v6address': [None],
#                 'v6data_port': ['16574'],
#                 'v6service_port': ['16574'],
#                 'desc': [defaultdict(list,
#                              {'channels': [defaultdict(list,
#                                            {'channel': [defaultdict(list,
#                                                          {'label': ['Stimulations'],
#                                                           'type': ['marker']})]})]})],
#                 'effective_srate': 0}),
#    'footer': {'info': defaultdict(list,
#                 {'first_timestamp': ['153.625'],
#                  'last_timestamp': ['600.828125'],
#                  'sample_count': ['589'],
#                  'clock_offsets': [defaultdict(list,
#                               {'offset': [defaultdict(list,
#                                             {'time': ['3148.30985875'],
#                                              'value': ['-1.904999999169377e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3153.31030665'],
#                                              'value': ['-1.24499999856198e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3158.3104564'],
#                                              'value': ['-1.119999978982378e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3163.31100545'],
#                                              'value': ['-2.764999999271822e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3168.31099075'],
#                                              'value': ['-8.449999995718827e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3173.3118216'],
#                                              'value': ['-3.15999998292682e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3178.31297365'],
#                                              'value': ['-9.449999879507232e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3183.313779900001'],
#                                              'value': ['-2.240000026176858e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3188.3142133'],
#                                              'value': ['-7.399999958579429e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3193.31459595'],
#                                              'value': ['5.000015335099306e-008']}),
#                                 defaultdict(list,
#                                             {'time': ['3198.31483245'],
#                                              'value': ['-2.014999972743681e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['
-007']}),
#                                 defaultdict(list,
#                                             {'time': ['3393.34760725'],
#                                              'value': ['8.500001058564521e-007']}),
#                                 defaultdict(list,
#                                             {'time': ['3398.3479443'],
#                                              'value': ['-2.810000000863511e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3403.34872775'],
#                                              'value': ['-1.255000006494811e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3408.3488243'],
#                                              'value': ['-1.96999999388936e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3413.34971295'],
#                                              'value': ['-1.450000127078965e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3418.35008505'],
#                                              'value': ['-1.34499998694082e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3423.3510678'],
#                                              'value': ['-3.639999977167463e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3428.35218545'],
#                                              'value': ['-3.234999985579634e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3433.35282235'],
#                                              'value': ['-2.665000010892982e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3438.35366605'],
#                                              'value': ['-4.949999947712058e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3443.3545144'],
#                                              'value': ['1.509999992777011e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3448.35491155'],
#                                              'value': ['-6.350000148813706e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3453.3556014'],
#                                              'value': ['-2.609999978631095e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3458.3558694'],
#                                              'value': ['-2.130000007127819e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3463.35679755'],
#                                              'value': ['-9.849999969446799e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3468.358438'],
#                                              'value': ['-8.199999911084888e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3473.35868025'],
#                                              'value': ['-1.550000206407276e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3478.35891675'],
#                                              'value': ['3.850000211969018e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3483.3594817'],
#                                              'value': ['-3.89999991057266e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3488.35990455'],
#                                              'value': ['5.650000048262882e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3493.3605244'],
#                                              'value': ['-3.499999820633093e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3498.3610092'],
#                                              'value': ['-7.000000096013537e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3503.361518600001'],
#                                              'value': ['-2.273736754432321e-013']}),
#                                 defaultdict(list,
#                                             {'time': ['3508.36243825'],
#                                              'value': ['-3.250000190746505e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3513.3643357'],
#                                              'value': ['-3.449999962867878e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3518.3645634'],
#                                              'value': ['-2.749999998741259e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3523.3653329'],
#                                              'value': ['-2.259999996567785e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3528.36549855'],
#                                              'value': ['4.450000005817856e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3533.3664851'],
#                                              'value': ['-3.029999993486854e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3538.3672057'],
#                                              'value': ['-1.580000002832094e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3543.36814275'],
#                                              'value': ['-3.57499998244748e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3548.368321550001'],
#                                              'value': ['-3.915000002052693e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3553.3692692'],
#                                              'value': ['-3.309999988232448e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3558.3702552'],
#                                              'value': ['-2.22999999550666e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3563.37018815'],
#                                              'value': ['-2.395000001342851e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3568.3710832'],
#                                              'value': ['3.099999958067201e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3573.3719532'],
#                                              'value': ['3.099999958067201e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3578.3719503'],
#                                              'value': ['2.99999987873889e-006']}),
#                                 defaultdict(list,
#                                             {'time': ['3583.3722693'],
#                                              'value': ['-2.289999974891543e-005']}),
#                                 defaultdict(list,
#                                             {'time': ['3588.37282345'],
#                                              'value': ['-2.95499999083404e-005']})]})]})},
#    'time_series': array([[1697.82055664, 1676.53845215, 3060.76928711, ..., 5685.12841797,
#            7339.35888672, 5448.07714844],
#           [7494.23095703, 8144.48730469, 1092.94873047, ..., 6308.84619141,
#             866.9230957 ,  992.94873047],
#           [2531.41015625, 8170.12841797, 3288.33325195, ..., 1354.74353027,
#            5681.02587891, 6151.79492188],
#           ...,
#           [4942.1796875 , 1081.28210449, 5022.69238281, ..., 7147.94873047,
#            4487.69238281, 7568.71777344],
#           [4875.12841797, 2670.12817383, 3483.71801758, ..., 3101.15380859,
#            1786.9230957 , 5664.35888672],
#           [4921.79492188,  151.4102478 , 3933.71801758, ..., 1723.33337402,
#            6260.38476562, 6463.46142578]]),
#    'time_stamps': array([153.62500095, 153.63281345, 153.64062595, ..., 600.9140614 ,
#           600.9218739 , 600.9296864 ])}],
#  {'info': defaultdict(list, {'version': ['1.0']})})

# %%
yoshe_xdf = "yoshe_test.xdf"
annach_xdf = "annachess_test.xdf"
annag_xdf = "annag_test.xdf"

current_xdf = annag_xdf

streams = xdf.load_xdf(current_xdf)

# Extract streams
unitystr_time_series     = streams[0][0]['time_series']
unitystr_time_stamps     = streams[0][0]['time_stamps']
unitystr_first_timestamp = np.float(unitystr_time_stamps[0])#np.float(streams[0][0]['footer']['info']['first_timestamp'][2])

eeg_time_series     = streams[0][2]['time_series']
eeg_time_stamps     = streams[0][2]['time_stamps']
eeg_first_timestamp = np.float(streams[0][2]['footer']['info']['first_timestamp'][0])

# Sampling frequency of the recorded eeg data
sfreq = np.float(streams[0][2]['info']['nominal_srate'][0])

#Convert labels to codes: 1-chose high, 2-chose low, 3- Reward high, 4-reward low, 5-no reward

for i in range (len(unitystr_time_series)):
    if "PressedHigh" in str(unitystr_time_series[i]):
        unitystr_time_series[i]=1
    elif "PressedLow" in str(unitystr_time_series[i]):
        unitystr_time_series[i]=2
    elif "RewardHigh" in str(unitystr_time_series[i]):
        unitystr_time_series[i]=3
    elif "RewardLow" in str(unitystr_time_series[i]):
        unitystr_time_series[i]=4
    elif "RewardNone" in str(unitystr_time_series[i]):
        unitystr_time_series[i]=5

#Code to cleanup and trim the mismatching unity timestamps

for i in range (len(unitystr_time_stamps)):
    if unitystr_time_stamps[i] < eeg_time_stamps[0]:
        unitystr_time_stamps[i] = 0
        unitystr_time_series[i] = 0
    if unitystr_time_stamps[i] > eeg_time_stamps[-1]:
        unitystr_time_stamps[i] = 0
        unitystr_time_series[i] = 0

C_unitystr_time_stamps = np.trim_zeros(unitystr_time_stamps)
C_unitystr_time_series = np.trim_zeros(unitystr_time_series)

# 14 channels: AF3, F7, F3, FC5, T7, P7, O1, O2, P8, T8, FC6, F4, F8, AF4
ch_names = ('AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4')

# Create the info file
info = mne.create_info(ch_names, sfreq, ch_types='eeg' )

# Convert first time to sample
first_samp = int(eeg_first_timestamp*sfreq)

# NB set the first sample to be able to align the events
raw = mne.io.RawArray(eeg_time_series.T, info, first_samp=first_samp)

montage = mne.channels.read_montage('standard_1020')

raw.set_montage(montage)

# Create a ne stimulation channels
info         = mne.create_info(['STI'], raw.info['sfreq'], ch_types=['stim'])
# Fill it with an vector of zeros
stim_data    = np.zeros((1, len(raw.times)))

stim_raw     = mne.io.RawArray(stim_data, info, first_samp=first_samp)

# Add the new channel to your dataset
raw.add_channels([stim_raw], force_update_info=False)

(C_unitystr_time_stamps*sfreq).astype('int')

# You need to build an array of events
events = np.array(((C_unitystr_time_stamps*sfreq).astype('int'), np.zeros((len(C_unitystr_time_series),)), np.squeeze([C_unitystr_time_series])))

# Add the openvibe events
raw.add_events(events.T, stim_channel='STI')

### Re-reference your data
raw.set_eeg_reference()

## evs should return the same 'events' array you used to create the channel ( I did it just to confirm that all the events are there)


# With the option output='onset' we find only 26 events NB EVENTS ARE VERY CLOSE (JUST 1 TIMESTAMP BETWEEN TWO EVENTS)
# If you set it to 'step' you will have back all the 52 events (but it does not make sense for epoching your data)



evs = mne.find_events(raw, stim_channel='STI', output='onset', shortest_event=1,
                         min_duration=1/raw.info['sfreq'])
print('Number of events found: %d' % len(evs))

# Pick the channels you want to include 
reject = dict(eeg=150e-6) # you can set a rejection threshold for bad data (NB in this case all data will be discarded)

baseline = (None,None)
picks = mne.pick_types(raw.info, meg=False, eeg=True, ecg=False, eog=False, stim=False, exclude=[])


# Define the beginning and the end of each epoch
tmin = -1.
tmax = 1

# Epoch the data around event 1 (here defined as "trial_start")
epochs =  mne.Epochs(raw, evs, tmin=tmin, tmax=tmax, 
                     baseline=baseline, preload=True, reject=None)

# Check if all the epochs (nr of trials in the experiment) were extracted
print('Number of epochs: %d' % len(epochs))

if current_xdf == yoshe_xdf:
    epochs_yoshe = epochs
if current_xdf == annach_xdf:
    epochs_annach = epochs
if current_xdf == annag_xdf:
    epochs_annag = epochs

print("")    
print("----------------")    
print(epochs_yoshe)
print("----------------")
print(epochs_annach)
print("----------------")
print(epochs_annag)
# Out:
# Creating RawArray with float64 data, n_channels=14, n_times=50824
#     Range : 8256 ... 59079 =     64.500 ...   461.555 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=50824
#     Range : 8256 ... 59079 =     64.500 ...   461.555 secs
# Ready.
# Applying average reference.
# Applying a custom EEG reference.
# 100 events found
# Event IDs: [1 2 3 4 5]
# Number of events found: 100
# 100 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 100 events and 257 original time points ...
# 0 bad epochs dropped
# Number of epochs: 100
#
# ----------------
# <Epochs  |   77 events (all good), -1 - 1 sec, baseline [None, None], ~2.3 MB, data loaded,
#  '1': 37
#  '2': 2
#  '3': 22
#  '5': 16>
# ----------------
# <Epochs  |   96 events (all good), -1 - 1 sec, baseline [None, None], ~2.9 MB, data loaded,
#  '1': 29
#  '2': 19
#  '3': 12
#  '4': 11
#  '5': 25>
# ----------------
# <Epochs  |   100 events (all good), -1 - 1 sec, baseline [None, None], ~3.0 MB, data loaded,
#  '1': 37
#  '2': 13
#  '3': 17
#  '4': 6
#  '5': 27>

# %%
epochs_all = mne.concatenate_epochs([epochs_yoshe, epochs_annach, epochs_annag])

print(epochs_all)
# Out:
# 273 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 bad epochs dropped
# <Epochs  |   273 events (all good), -1 - 1 sec, baseline [None, None], ~8.1 MB, data loaded,
#  '1': 103
#  '2': 34
#  '3': 51
#  '4': 17
#  '5': 68>

# %% [markdown]
# mne extract power; take windows of 100ms and average the values of these (windowlength and overlapping of the time windows is up to us)or 500ms and moving of 200, etc normally overlapping is 80%. it will be a vector of all the freq values of this timeframe and those can be fed to the network. he suggests recurrent network. make it parametric so we can modify variables. important to put labels

# %%
from mne import Epochs, pick_types, find_events
from mne.channels import read_layout
from mne.io import concatenate_raws, read_raw_edf
from mne.datasets import eegbci
from mne.decoding import CSP

from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import ShuffleSplit, cross_val_score, cross_validate

this_epoch = epochs_all

this_epoch.drop_channels(['AF3','F7', "F3", "FC5", 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', "F4", 'F8', "AF4"])

epochs_train = this_epoch.copy()
labels = this_epoch.events[:, -1]


# Define a monte-carlo cross-validation generator (reduce variance):
scores = []
epochs_data = this_epoch.get_data()
epochs_data_train = epochs_train.get_data()


#cv = ShuffleSplit(10, test_size=0.2, random_state=42)
#cv_split = cv.split(epochs_data_train)
# Generate 10 folds for cross-validation using 20% of data as test set
cv = ShuffleSplit(10, test_size=.2, random_state=42)
cv_split = cv.split(epochs_train)

# Assemble a classifier
lda = LinearDiscriminantAnalysis()
#csp = CSP(n_components=4, reg=None, log=True, norm_trace=False)
csp = CSP(n_components=4, reg='ledoit_wolf', log=None, cov_est='epoch', norm_trace=False)

#for i in epochs_data_train:
    #print(i.shape)

# Use scikit-learn Pipeline with cross_val_score function
clf = Pipeline([('CSP', csp), ('LDA', lda)])
scores = cross_val_score(clf, epochs_data_train, labels, cv=cv)

# Printing the results
class_balance = np.mean(labels == labels[0])
class_balance = max(class_balance, 1. - class_balance)
print("Classification accuracy: %f / Chance level: %f" % (np.mean(scores),
                                                          class_balance))

# plot CSP patterns estimated on full data for visualization
csp.fit_transform(epochs_data, labels)

layout = read_layout('EEG1005')
csp.plot_patterns(this_epoch.info, layout=layout, ch_type='eeg',
                  units='Patterns (AU)', size=1.5)
# Out:
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\pipeline.py:581: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   res = transformer.fit_transform(X, y, **fit_params)
# ...
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# <ipython-input-38-bfdb38e996dc>:50: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   csp.fit_transform(epochs_data, labels)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-bfdb38e996dc> in <module>()
#      52 layout = read_layout('EEG1005')
#      53 csp.plot_patterns(this_epoch.info, layout=layout, ch_type='eeg',
# ---> 54                   units='Patterns (AU)', size=1.5)
#
# D:\python\lib\site-packages\mne\decoding\csp.py in plot_patterns(self, info, components, ch_type, layout, vmin, vmax, cmap, sensors, colorbar, scalings, units, res, size, cbar_fmt, name_format, show, show_names, title, mask, mask_params, outlines, contours, image_interp, average, head_pos)
#     437             title=title, mask_params=mask_params, mask=mask, outlines=outlines,
#     438             contours=contours, image_interp=image_interp, show=show,
# --> 439             average=average, head_pos=head_pos)
#     440
#     441     def plot_filters(self, info, components=None, ch_type=None, layout=None,
#
# D:\python\lib\site-packages\mne\evoked.py in plot_topomap(self, times, ch_type, layout, vmin, vmax, cmap, sensors, colorbar, scalings, units, res, size, cbar_fmt, time_unit, time_format, proj, show, show_names, title, mask, mask_params, outlines, contours, image_interp, average, head_pos, axes)
#     359             mask_params=mask_params, outlines=outlines, contours=contours,
#     360             image_interp=image_interp, average=average, head_pos=head_pos,
# --> 361             axes=axes)
#     362
#     363     @copy_function_doc_to_method_doc(plot_evoked_field)
#
# D:\python\lib\site-packages\mne\viz\topomap.py in plot_evoked_topomap(***failed resolving arguments***)
#    1520             min(times) < min(evoked.times) - space):
#    1521         raise ValueError('Times should be between {0:0.3f} and '
# -> 1522                          '{1:0.3f}.'.format(evoked.times[0], evoked.times[-1]))
#    1523     n_times = len(times)
#    1524     nax = n_times + bool(colorbar)
#
# ValueError: Times should be between 0.000 and 1.000.

# %%
layout = read_layout('EEG1005')
csp.plot_patterns(this_epoch.info, layout=layout, ch_type='eeg',
                  units='Patterns (AU)', size=1.5)

print("Classification accuracy: %f / Chance level: %f" % (np.mean(scores),
                                                          class_balance))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-76a22c5cdf01> in <module>()
#       1 layout = read_layout('EEG1005')
#       2 csp.plot_patterns(this_epoch.info, layout=layout, ch_type='eeg',
# ----> 3                   units='Patterns (AU)', size=1.5)
#       4
#       5 print("Classification accuracy: %f / Chance level: %f" % (np.mean(scores),
#
# D:\python\lib\site-packages\mne\decoding\csp.py in plot_patterns(self, info, components, ch_type, layout, vmin, vmax, cmap, sensors, colorbar, scalings, units, res, size, cbar_fmt, name_format, show, show_names, title, mask, mask_params, outlines, contours, image_interp, average, head_pos)
#     437             title=title, mask_params=mask_params, mask=mask, outlines=outlines,
#     438             contours=contours, image_interp=image_interp, show=show,
# --> 439             average=average, head_pos=head_pos)
#     440
#     441     def plot_filters(self, info, components=None, ch_type=None, layout=None,
#
# D:\python\lib\site-packages\mne\evoked.py in plot_topomap(self, times, ch_type, layout, vmin, vmax, cmap, sensors, colorbar, scalings, units, res, size, cbar_fmt, time_unit, time_format, proj, show, show_names, title, mask, mask_params, outlines, contours, image_interp, average, head_pos, axes)
#     359             mask_params=mask_params, outlines=outlines, contours=contours,
#     360             image_interp=image_interp, average=average, head_pos=head_pos,
# --> 361             axes=axes)
#     362
#     363     @copy_function_doc_to_method_doc(plot_evoked_field)
#
# D:\python\lib\site-packages\mne\viz\topomap.py in plot_evoked_topomap(***failed resolving arguments***)
#    1520             min(times) < min(evoked.times) - space):
#    1521         raise ValueError('Times should be between {0:0.3f} and '
# -> 1522                          '{1:0.3f}.'.format(evoked.times[0], evoked.times[-1]))
#    1523     n_times = len(times)
#    1524     nax = n_times + bool(colorbar)
#
# ValueError: Times should be between 0.000 and 1.000.

# %%
sfreq = raw.info['sfreq']
w_length = int(sfreq * 0.5)   # running classifier: window length
w_step = int(sfreq * 0.1)  # running classifier: window step size
w_start = np.arange(0, epochs_data.shape[2] - w_length, w_step)

scores_windows = []

for train_idx, test_idx in cv_split:
    y_train, y_test = labels[train_idx], labels[test_idx]

    X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
    X_test = csp.transform(epochs_data_train[test_idx])

    # fit classifier
    lda.fit(X_train, y_train)

    # running classifier: test classifier on sliding window
    score_this_window = []
    for n in w_start:
        X_test = csp.transform(epochs_data[test_idx][:, :, n:(n + w_length)])
        score_this_window.append(lda.score(X_test, y_test))
    scores_windows.append(score_this_window)

# Plot scores over time
w_times = (w_start + w_length / 2.) / sfreq + this_epoch.tmin

plt.figure()
plt.plot(w_times, np.mean(scores_windows, 0), label='Score')
plt.axvline(0, linestyle='--', color='k', label='Onset')
plt.axhline(0.5, linestyle='-', color='k', label='Chance')
plt.xlabel('time (s)')
plt.ylabel('classification accuracy')
plt.title('Classification score over time')
plt.legend(loc='lower right')
plt.show()
# Out:
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# ...
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# Estimating covariance using LEDOIT_WOLF
# Done.
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
# <ipython-input-39-8349595b3fe3>:11: DeprecationWarning: rank defaults to "full" in 0.17 but will change to None in 0.18, set it explicitly to avoid this warning
#   X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
